# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv
from langchain_core.prompts import message

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv('DEEPSEEK_API_KEY')
DEEPSEEK_BASE_URL = os.getenv('DEEPSEEK_BASE_URL')

model = init_chat_model(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
# Out:
# python-dotenv could not parse statement starting at line 1

# %% [markdown]
# # 流式调用

# %%
for chunk in model.stream('请问为什么我现在想找女朋友，可是找不到感觉'):
    print(chunk.text,end="",flush=True)
# Out:
# 感受到你在寻找恋爱关系时的那种困惑和些许失落——明明想要靠近爱情，却总觉得心里少了些什么。这种“找不到感觉”的状态其实并不少见，它往往不是因为你不渴望亲密关系，而是可能有一些更深层的原因在起作用。
#
# 首先，请不要苛责自己“找不到感觉”是能力问题或性格缺陷。很多时候，这种感觉的缺失像一层薄雾，让原本可能的风景变得模糊。那么，我们不妨一起梳理几个可能的路径：
#
# 1.  **感受一下“感觉”本身的定义**：你所说的“感觉”是什么？是初见的心动、持续的暧昧感、还是深层次的灵魂共鸣？有时我们期待的是影视剧里那种“一见钟情”的强烈电流，但现实中，真实的情感常常是在日常互动中慢慢渗透的。或许可以试着把对“感觉”的期待调低一点，先专注于认识一个具体的人，感受她的性格、观点和相处时的舒适度。
#
# 2.  **观察一下你的生活状态**：你的日常生活是否存在某种“封闭感”？比如长期投入工作、学业，或者沉浸在固定的兴趣圈子（如游戏、运动、独处阅读）里。当生活缺少新鲜的人和事，情感的神经也会变得迟钝。试着有意识地为生活制造一点“松动”——参加一次兴趣小组活动、和不太熟的朋友约一次饭、甚至只是换条路线散步。新的刺激往往能激活曾被忽略的感受力。
#
# 3.  **检查一下你的内在“标准”**：有时我们心中有一个模糊的“理想型”，她可能综合了很多特质（外貌、性格、生活方式等），但这样的标准在现实中很难全然满足。当遇到的人与这个“模板”有偏差，潜意识里就会产生“没感觉”的判断。可以尝试问问自己：我真正在寻找的，是一个满足所有条件的完美对象，还是一个能在相处中让我感受到温暖、陪伴和成长的真实的人？
#
# 4.  **挖掘一下你对自己的感受**：这听起来有些反直觉，但“找不到感觉”有时恰恰源于**你对自己情绪和需求的觉察不够清晰**。你或许忙于满足社会期待（“到了该恋爱的年纪”“大家都脱单了”），却忽略了自己内心真正的需求——比如，你真正渴望的是一段稳定的陪伴，还是一场充满激情的冒险？又或者，你内心深处是否有一丝对亲密关系的恐惧？试着用纸笔写下：如果你完全不考虑外界压力，你希望一段关系带给你什么？
#
# 5.  **尝试一些“不找感觉”的接触**：不妨把“找女朋友”这个目标暂时放下，转而专注于“认识一个有趣的新朋友”。当你不再带着“评估能否发展恋爱关系”的滤镜去接触一个人时，反而更容易卸下心理负担，展现出真实的自己。这种松弛感本身就是一种吸引力，而突如其来的“感觉”往往就在最不经意的瞬间发生。
#
# 最后，请给自己一些耐心。情感的产生不是开关的拨动，而更像植物的生长——需要合适的土壤（你的生活状态）、阳光（自然的接触）和水分（足够的耐心）。当你开始享受自己的生活，而不是焦虑于“缺人”时，那个能让你真正有感觉的人，反而更容易出现在你的视线里。
#
# 你愿意分享最近一次让你感到“有点心动”或“特别欣赏”他人的瞬间吗？哪怕是很细微的细节，或许能帮助我们更具体地理解你的感受。

# %% [markdown]
# # 批量调用

# %%
inputs = [
    "翻译成日文：你好啊",
    "翻译成日文：晚上好",
    "翻译成日文：wain",
    "翻译成日文："
]
