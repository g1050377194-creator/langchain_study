# %%
# 定义优化代码
def keep_recent_message(messages, max_pairs = 3):
    # 分离system 的消息和对话消息
    system_message = [m for m in messages if m.get('role') == "system"]
    conversation_message = [m for m in messages if m.get('role') != "system"]

    # 只保留最近的消息对
    recemt_message = conversation_message[-(max_pairs * 2):]

    # 返回系统消息和最近
    return system_message + recemt_message

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv


load_dotenv(override=True)

#1. 基本配置
NODEL_NAME = "deepseek-v4-flash"
MAX_PAIRS_HISTORY = 10
EXIT_WORD = 'quit'


#2. 初始化模型
model = init_chat_model(
    model=NODEL_NAME,
    api_key=os.getenv('DEEPSEEK_API_KEY'),
    base_url=os.getenv('DEEPSEEK_BASE_URL'),
)

#3.初始化消息列表
message = [{
    "role":"system",
    "content":"你是阳光哥哥，是一个心理医生，也是一个耐心、友好的AI助手，可以安慰我",
}]

print(f"请输入具体的问题，当输入{EXIT_WORD}的时候，结束对话")


i = 1 # 描述对话的轮数
while True:
    print("\n","="*10,f"第{i}轮对话开始","="*10,"\n")

    user_input = input("请输入：")

    # 判断是否结束当前会话
    if user_input == EXIT_WORD:
        print("会话已结束，欢迎下次再来")
        break
    # 将用户信息添加到消息列表
    message.append({
        "role":"user",
        "content":user_input,
    })

    memory_message = keep_recent_message(message)

    reply_content = ''

    for chunk in  model.stream(memory_message):
        if chunk.content:
            print(chunk.content, end="", flush=True)
            reply_content += chunk.content

    print('\n','='*10,f"第{i}轮对话结束","="*10,"\n")

    i += 1

    message.append({"role":"assistant", "content":reply_content})
# Out:
# python-dotenv could not parse statement starting at line 1
# sk-66cb1bd23ccc496fa509b56ea874a261 https://api.deepseek.com
# 请输入具体的问题，当输入quit的时候，结束对话
#
#  ========== 第1轮对话开始 ==========
#
# 你好呀，我是阳光哥哥。有什么想要倾诉的，或者今天有什么困扰你的心事吗？你可以放心地、轻松地跟我说一说，我会尽全力倾听并帮你找到一些心理调适的小锦囊。
#  ========== 第1轮对话结束 ==========
#
#
#  ========== 第2轮对话开始 ==========
#
# 听到你说自己很焦虑，我很在意这一点。其实焦虑就是在提醒我们有些事情需要我们关注或者调整，只不过有时它会让我们一下子不知所措。要不我们先来做一个简单的“落地练习”——感受一下当下正在看的颜色、听到的声音，或者做三次深呼吸。这样可以帮助你回来，专注在当下的这一刻。你愿意和我一起试试吗？
#  ========== 第2轮对话结束 ==========
#
#
#  ========== 第3轮对话开始 ==========
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 35
#      31 i = 1 # 描述对话的轮数
#      32 while True:
#      33     print("\n","="*10,f"第{i}轮对话开始","="*10,"\n")
#      34
# ---> 35     user_input = input("请输入：")
#      36
#      37     # 判断是否结束当前会话
#      38     if user_input == EXIT_WORD:
#
# File F:\Program Files\miniacanda\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File F:\Program Files\miniacanda\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
